# %% [markdown]
#  # Consolidate Entities
#  All csv files under slp/__entity__/ into one single file representing all terms entities.
#
#  Please run __Senators__ and __Congressmen__ notebooks in order to update the files to the latest update.

# %%
import glob # linux glob wrapper allows us to list directory using regex expressions
import pandas as pd # provides join functionality and named-column manipulation
import os
SLP_PATH = 'datasets/slp/'
AGENTS_PATH = '{:}agents/'.format(SLP_PATH)
ORGANIZATIONS_PATH = '{:}organizations/'.format(SLP_PATH)
MEMBERSHIPS_PATH = '{:}memberships/'.format(SLP_PATH)

# %%
def upsert_by_prov(entity_path, prov):
    '''
        Performs upsert (Update/Insert) of all files with the same provenance
        
        args:
            entity_path .: string containing the path
            prov        .: string in ('cam', 'sen')
        
    '''
    if prov not in ('cam', 'sen'):
        raise ValueError('The only provs suported are (\'cam\', \'sen\') got {:}'.format(prov))    

    df = None    
    # Gets every directory under entity path - with terms sorted asc    
    entity_terms = sorted( glob.glob('{:}*[0-9]'.format(entity_path)) )
    for et in entity_terms:
        filenames = glob.glob('{:}/*{:}.csv'.format(et, prov))
        df = pd.read_csv(filenames[0], sep= ';', header=0, index_col='slp:resource_uri', encoding='utf-8')
        
        for fn in filenames[1:]:
            _df = pd.read_csv(fn, sep= ';', header=0, index_col='slp:resource_uri', encoding='utf-8')            
            # upsert : concatenate or insert
            df = pd.concat([df[~df.index.isin(_df.index)], _df])

    return df

# %% [markdown]
#  ## 1. Agents
#
#  ### 1.1 Upsert camara

# %%
dataframes = [] 
df = upsert_by_prov(AGENTS_PATH, 'cam')
print('Table camara shape:', df.shape)
columns = df.columns
dataframes.append(df)
df.head()
# Out:
# Table camara shape: (606, 5)
#                                      cam:dataFalecimento cam:dataNascimento  \
# slp:resource_uri
# 64965d06-916a-4ef9-a8c7-886055dc979e                 NaN         1976-10-23
# 908bcac7-6fc7-4957-9ae9-00a46ad10a37                 NaN         1969-02-13
# 5ff9cfe9-2fee-47b6-b7ac-a1cb282236be                 NaN         1987-02-10
# e4e93a22-8177-400a-8231-2e8ae9d06a12                 NaN         1960-10-15
# 0a39e693-7990-4118-8637-278d778df124                 NaN         1956-02-05
#
#                                       cam:ideCadastro  \
# slp:resource_uri
# 64965d06-916a-4ef9-a8c7-886055dc979e           178836
# 908bcac7-6fc7-4957-9ae9-00a46ad10a37           160527
# 5ff9cfe9-2fee-47b6-b7ac-a1cb282236be           160582
# e4e93a22-8177-400a-8231-2e8ae9d06a12           160508
# 0a39e693-7990-4118-8637-278d778df124           178903
#
#                                                            cam:nomeCivil  \
# slp:resource_uri
# 64965d06-916a-4ef9-a8c7-886055dc979e                   ALAN RICK MIRANDA
# 908bcac7-6fc7-4957-9ae9-00a46ad10a37    AGUINALDO VELLOSO BORGES RIBEIRO
# 5ff9cfe9-2fee-47b6-b7ac-a1cb282236be  JOSÉ ALBERTO OLIVEIRA VELOSO FILHO
# e4e93a22-8177-400a-8231-2e8ae9d06a12            AFONSO BANDEIRA FLORENCE
# 0a39e693-7990-4118-8637-278d778df124           ADILTON DOMINGOS SACHETTI
#
#                                      cam:nomeParlamentarAtual
# slp:resource_uri
# 64965d06-916a-4ef9-a8c7-886055dc979e                ALAN RICK
# 908bcac7-6fc7-4957-9ae9-00a46ad10a37        AGUINALDO RIBEIRO
# 5ff9cfe9-2fee-47b6-b7ac-a1cb282236be            ALBERTO FILHO
# e4e93a22-8177-400a-8231-2e8ae9d06a12          AFONSO FLORENCE
# 0a39e693-7990-4118-8637-278d778df124         ADILTON SACHETTI

# %% [markdown]
#  ### 1.2 Upsert senado

# %%
df  = upsert_by_prov(AGENTS_PATH, 'sen')
print('Table senado shape:', df.shape)
columns = df.columns.union(columns)
dataframes.append(df)
df.head()
# Out:
# Table senado shape: (252, 3)
#                                       sen:CodigoParlamentar  \
# slp:resource_uri
# 828a0e78-b457-47de-8112-a7cce8d24563                   5573
# 59888f36-89fc-40e9-adf7-e95bb4906eb2                    739
# 94be5f0e-2cc9-488b-bb32-335a44eb4f1b                   5108
# 40260ab9-9261-46b9-8ab3-3c569dfa8b24                   5136
# ad36f1e7-f24a-4f51-9f44-c45468e0d4a1                   5623
#
#                                        sen:NomeCompletoParlamentar  \
# slp:resource_uri
# 828a0e78-b457-47de-8112-a7cce8d24563        Abel Rebouças São José
# 59888f36-89fc-40e9-adf7-e95bb4906eb2      Ciro Nogueira Lima Filho
# 94be5f0e-2cc9-488b-bb32-335a44eb4f1b     José Aparecido dos Santos
# 40260ab9-9261-46b9-8ab3-3c569dfa8b24        Cesar Antonio de Souza
# ad36f1e7-f24a-4f51-9f44-c45468e0d4a1  Christopher Belchior Goulart
#
#                                          sen:NomeParlamentar
# slp:resource_uri
# 828a0e78-b457-47de-8112-a7cce8d24563           Abel Rebouças
# 59888f36-89fc-40e9-adf7-e95bb4906eb2           Ciro Nogueira
# 94be5f0e-2cc9-488b-bb32-335a44eb4f1b          Cidinho Santos
# 40260ab9-9261-46b9-8ab3-3c569dfa8b24  Cesar Antonio de Souza
# ad36f1e7-f24a-4f51-9f44-c45468e0d4a1     Christopher Goulart

# %% [markdown]
#  ### 1.3 Integrate

# %%
for _df in dataframes:
    _df = _df.reindex(columns=columns, fill_value=None)

df = pd.concat(dataframes, axis=0)    
print('Table agents', _df.shape)
df.head()
# Out:
# Table agents (252, 8)
#                                      cam:dataFalecimento cam:dataNascimento  \
# slp:resource_uri
# 64965d06-916a-4ef9-a8c7-886055dc979e                 NaN         1976-10-23
# 908bcac7-6fc7-4957-9ae9-00a46ad10a37                 NaN         1969-02-13
# 5ff9cfe9-2fee-47b6-b7ac-a1cb282236be                 NaN         1987-02-10
# e4e93a22-8177-400a-8231-2e8ae9d06a12                 NaN         1960-10-15
# 0a39e693-7990-4118-8637-278d778df124                 NaN         1956-02-05
#
#                                       cam:ideCadastro  \
# slp:resource_uri
# 64965d06-916a-4ef9-a8c7-886055dc979e         178836.0
# 908bcac7-6fc7-4957-9ae9-00a46ad10a37         160527.0
# 5ff9cfe9-2fee-47b6-b7ac-a1cb282236be         160582.0
# e4e93a22-8177-400a-8231-2e8ae9d06a12         160508.0
# 0a39e693-7990-4118-8637-278d778df124         178903.0
#
#                                                            cam:nomeCivil  \
# slp:resource_uri
# 64965d06-916a-4ef9-a8c7-886055dc979e                   ALAN RICK MIRANDA
# 908bcac7-6fc7-4957-9ae9-00a46ad10a37    AGUINALDO VELLOSO BORGES RIBEIRO
# 5ff9cfe9-2fee-47b6-b7ac-a1cb282236be  JOSÉ ALBERTO OLIVEIRA VELOSO FILHO
# e4e93a22-8177-400a-8231-2e8ae9d06a12            AFONSO BANDEIRA FLORENCE
# 0a39e693-7990-4118-8637-278d778df124           ADILTON DOMINGOS SACHETTI
#
#                                      cam:nomeParlamentarAtual  \
# slp:resource_uri
# 64965d06-916a-4ef9-a8c7-886055dc979e                ALAN RICK
# 908bcac7-6fc7-4957-9ae9-00a46ad10a37        AGUINALDO RIBEIRO
# 5ff9cfe9-2fee-47b6-b7ac-a1cb282236be            ALBERTO FILHO
# e4e93a22-8177-400a-8231-2e8ae9d06a12          AFONSO FLORENCE
# 0a39e693-7990-4118-8637-278d778df124         ADILTON SACHETTI
#
#                                       sen:CodigoParlamentar  \
# slp:resource_uri
# 64965d06-916a-4ef9-a8c7-886055dc979e                    NaN
# 908bcac7-6fc7-4957-9ae9-00a46ad10a37                    NaN
# 5ff9cfe9-2fee-47b6-b7ac-a1cb282236be                    NaN
# e4e93a22-8177-400a-8231-2e8ae9d06a12                    NaN
# 0a39e693-7990-4118-8637-278d778df124                    NaN
#
#                                      sen:NomeCompletoParlamentar  \
# slp:resource_uri
# 64965d06-916a-4ef9-a8c7-886055dc979e                         NaN
# 908bcac7-6fc7-4957-9ae9-00a46ad10a37                         NaN
# 5ff9cfe9-2fee-47b6-b7ac-a1cb282236be                         NaN
# e4e93a22-8177-400a-8231-2e8ae9d06a12                         NaN
# 0a39e693-7990-4118-8637-278d778df124                         NaN
#
#                                      sen:NomeParlamentar
# slp:resource_uri
# 64965d06-916a-4ef9-a8c7-886055dc979e                 NaN
# 908bcac7-6fc7-4957-9ae9-00a46ad10a37                 NaN
# 5ff9cfe9-2fee-47b6-b7ac-a1cb282236be                 NaN
# e4e93a22-8177-400a-8231-2e8ae9d06a12                 NaN
# 0a39e693-7990-4118-8637-278d778df124                 NaN

# %% [markdown]
#  ### 1.4 Save

# %%
filename = '{:}agents.csv'.format(SLP_PATH)
df.to_csv(filename, sep=';', index=True, encoding='utf-8')

# %% [markdown]
#  ## 2. Memberships
#  ### 2.1 Upsert camara

# %%
dataframes=[]
df = upsert_by_prov(MEMBERSHIPS_PATH, 'cam')
columns = df.columns
dataframes.append(df)
print(df.shape)
df.head()
# Out:
# (954, 7)
#                                      cam:dataFim cam:dataInicio  \
# slp:resource_uri
# 9589fe93-2270-4940-be3c-706111bf6b69         NaN     2015-02-01
# e896acb8-0da3-4e4a-b235-355c1a01f7cb         NaN     2015-02-01
# 30eb6da8-3308-45a0-bfd8-0f6f9884133c         NaN     2015-02-01
# 76e294dc-7b1a-48d5-8f15-6888f59c42d2  2017-10-30     2015-02-01
# 39df2d4d-6954-4abf-909f-7ab27d22870f         NaN     2015-02-01
#
#                                      cam:siglaUFRepresentacao  \
# slp:resource_uri
# 9589fe93-2270-4940-be3c-706111bf6b69                       AC
# e896acb8-0da3-4e4a-b235-355c1a01f7cb                       PB
# 30eb6da8-3308-45a0-bfd8-0f6f9884133c                       BA
# 76e294dc-7b1a-48d5-8f15-6888f59c42d2                       MT
# 39df2d4d-6954-4abf-909f-7ab27d22870f                       RS
#
#                                                                 org:member  \
# slp:resource_uri
# 9589fe93-2270-4940-be3c-706111bf6b69  64965d06-916a-4ef9-a8c7-886055dc979e
# e896acb8-0da3-4e4a-b235-355c1a01f7cb  908bcac7-6fc7-4957-9ae9-00a46ad10a37
# 30eb6da8-3308-45a0-bfd8-0f6f9884133c  e4e93a22-8177-400a-8231-2e8ae9d06a12
# 76e294dc-7b1a-48d5-8f15-6888f59c42d2  0a39e693-7990-4118-8637-278d778df124
# 39df2d4d-6954-4abf-909f-7ab27d22870f  abf442cf-ef29-40f6-8929-9a4066570ed2
#
#                                                                   org:post  \
# slp:resource_uri
# 9589fe93-2270-4940-be3c-706111bf6b69  66884075-6a00-485e-9dc9-792f9b34e035
# e896acb8-0da3-4e4a-b235-355c1a01f7cb  a8b6f47f-5ff8-489b-8c27-f6880bc0fb54
# 30eb6da8-3308-45a0-bfd8-0f6f9884133c  826e5566-26d8-4dfd-ad92-c81039336f0e
# 76e294dc-7b1a-48d5-8f15-6888f59c42d2  fca05d26-d58d-4289-b0d9-ecffccf678d4
# 39df2d4d-6954-4abf-909f-7ab27d22870f  70fd1e05-d6d4-46ca-98bf-82a207d04d7c
#
#                                                                 org:postIn  \
# slp:resource_uri
# 9589fe93-2270-4940-be3c-706111bf6b69  c8f660fd-7d0b-48e5-8513-2f7f0bb5f91c
# e896acb8-0da3-4e4a-b235-355c1a01f7cb  c8f660fd-7d0b-48e5-8513-2f7f0bb5f91c
# 30eb6da8-3308-45a0-bfd8-0f6f9884133c  c8f660fd-7d0b-48e5-8513-2f7f0bb5f91c
# 76e294dc-7b1a-48d5-8f15-6888f59c42d2  c8f660fd-7d0b-48e5-8513-2f7f0bb5f91c
# 39df2d4d-6954-4abf-909f-7ab27d22870f  c8f660fd-7d0b-48e5-8513-2f7f0bb5f91c
#
#                                                                   org:role
# slp:resource_uri
# 9589fe93-2270-4940-be3c-706111bf6b69  b27beba7-ca02-4041-a9e0-1793bcd141fe
# e896acb8-0da3-4e4a-b235-355c1a01f7cb  b27beba7-ca02-4041-a9e0-1793bcd141fe
# 30eb6da8-3308-45a0-bfd8-0f6f9884133c  b27beba7-ca02-4041-a9e0-1793bcd141fe
# 76e294dc-7b1a-48d5-8f15-6888f59c42d2  b27beba7-ca02-4041-a9e0-1793bcd141fe
# 39df2d4d-6954-4abf-909f-7ab27d22870f  b27beba7-ca02-4041-a9e0-1793bcd141fe

# %% [markdown]
#  ### 2.2 Upsert senado

# %%
df  = upsert_by_prov(MEMBERSHIPS_PATH, 'sen')
print('Table senado shape:', df.shape)
columns = df.columns.union(columns)
dataframes.append(df)
df.head()
# Out:
# Table senado shape: (856, 12)
#                                          DataFim  DataInicio  \
# slp:resource_uri
# 61e28c9c-c93b-40fc-a73d-3a963632df24  2019-01-31  2015-02-01
# 669716c0-cf09-4d77-896b-8497c3943b34  2023-01-31  2019-02-01
# 869d897d-3ab6-448a-ba58-8c18a2aa4421  2015-01-31  2011-02-01
# 155310d6-40c8-4c04-9234-6f312193b877  2019-01-31  2015-02-01
# 3e9c9056-8f75-4d44-b5a3-da45f12caa33  2015-01-31  2011-02-01
#
#                                       NumeroLegislatura  \
# slp:resource_uri
# 61e28c9c-c93b-40fc-a73d-3a963632df24               55.0
# 669716c0-cf09-4d77-896b-8497c3943b34               56.0
# 869d897d-3ab6-448a-ba58-8c18a2aa4421               54.0
# 155310d6-40c8-4c04-9234-6f312193b877               55.0
# 3e9c9056-8f75-4d44-b5a3-da45f12caa33               54.0
#
#                                                                 org:member  \
# slp:resource_uri
# 61e28c9c-c93b-40fc-a73d-3a963632df24  828a0e78-b457-47de-8112-a7cce8d24563
# 669716c0-cf09-4d77-896b-8497c3943b34  828a0e78-b457-47de-8112-a7cce8d24563
# 869d897d-3ab6-448a-ba58-8c18a2aa4421  59888f36-89fc-40e9-adf7-e95bb4906eb2
# 155310d6-40c8-4c04-9234-6f312193b877  59888f36-89fc-40e9-adf7-e95bb4906eb2
# 3e9c9056-8f75-4d44-b5a3-da45f12caa33  94be5f0e-2cc9-488b-bb32-335a44eb4f1b
#
#                                                                   org:post  \
# slp:resource_uri
# 61e28c9c-c93b-40fc-a73d-3a963632df24  557ddf29-a108-4f60-9bea-08c9eb164aab
# 669716c0-cf09-4d77-896b-8497c3943b34  804a0dd6-37d9-448c-9a1b-fd47737a6684
# 869d897d-3ab6-448a-ba58-8c18a2aa4421  d1f2997c-db50-458e-a53b-07df441ae6d0
# 155310d6-40c8-4c04-9234-6f312193b877  47fe43d9-8020-471f-90fc-9432a6227492
# 3e9c9056-8f75-4d44-b5a3-da45f12caa33  d0fc7898-63b2-454e-8a3a-882652c63d14
#
#                                                                 org:postIn  \
# slp:resource_uri
# 61e28c9c-c93b-40fc-a73d-3a963632df24  81311052-e5b6-46fe-87ba-83865fa0ffb0
# 669716c0-cf09-4d77-896b-8497c3943b34  81311052-e5b6-46fe-87ba-83865fa0ffb0
# 869d897d-3ab6-448a-ba58-8c18a2aa4421  81311052-e5b6-46fe-87ba-83865fa0ffb0
# 155310d6-40c8-4c04-9234-6f312193b877  81311052-e5b6-46fe-87ba-83865fa0ffb0
# 3e9c9056-8f75-4d44-b5a3-da45f12caa33  81311052-e5b6-46fe-87ba-83865fa0ffb0
#
#                                                                   org:role  \
# slp:resource_uri
# 61e28c9c-c93b-40fc-a73d-3a963632df24  d69fcc38-21a6-41ee-8c0f-90be24aff805
# 669716c0-cf09-4d77-896b-8497c3943b34  d69fcc38-21a6-41ee-8c0f-90be24aff805
# 869d897d-3ab6-448a-ba58-8c18a2aa4421  d69fcc38-21a6-41ee-8c0f-90be24aff805
# 155310d6-40c8-4c04-9234-6f312193b877  d69fcc38-21a6-41ee-8c0f-90be24aff805
# 3e9c9056-8f75-4d44-b5a3-da45f12caa33  d69fcc38-21a6-41ee-8c0f-90be24aff805
#
#                                       sen:CodigoMandato sen:DataDesfiliacao  \
# slp:resource_uri
# 61e28c9c-c93b-40fc-a73d-3a963632df24              492.0                 NaN
# 669716c0-cf09-4d77-896b-8497c3943b34              492.0                 NaN
# 869d897d-3ab6-448a-ba58-8c18a2aa4421              458.0                 NaN
# 155310d6-40c8-4c04-9234-6f312193b877              458.0                 NaN
# 3e9c9056-8f75-4d44-b5a3-da45f12caa33              456.0                 NaN
#
#                                      sen:DataFiliacao sen:SiglaPartido  \
# slp:resource_uri
# 61e28c9c-c93b-40fc-a73d-3a963632df24              NaN              NaN
# 669716c0-cf09-4d77-896b-8497c3943b34              NaN              NaN
# 869d897d-3ab6-448a-ba58-8c18a2aa4421              NaN              NaN
# 155310d6-40c8-4c04-9234-6f312193b877              NaN              NaN
# 3e9c9056-8f75-4d44-b5a3-da45f12caa33              NaN              NaN
#
#                                      sen:UfParlamentar
# slp:resource_uri
# 61e28c9c-c93b-40fc-a73d-3a963632df24                BA
# 669716c0-cf09-4d77-896b-8497c3943b34                BA
# 869d897d-3ab6-448a-ba58-8c18a2aa4421                PI
# 155310d6-40c8-4c04-9234-6f312193b877                PI
# 3e9c9056-8f75-4d44-b5a3-da45f12caa33                MT

# %% [markdown]
#  ### 2.3 Integrate

# %%
for _df in dataframes:
    _df = _df.reindex(columns=columns, fill_value=None)

df = pd.concat(dataframes, axis=0)    
print('Table memberships', df.shape)
df.head()
# Out:
# Table memberships (1810, 15)
#                                      DataFim DataInicio  NumeroLegislatura  \
# slp:resource_uri
# 9589fe93-2270-4940-be3c-706111bf6b69     NaN        NaN                NaN
# e896acb8-0da3-4e4a-b235-355c1a01f7cb     NaN        NaN                NaN
# 30eb6da8-3308-45a0-bfd8-0f6f9884133c     NaN        NaN                NaN
# 76e294dc-7b1a-48d5-8f15-6888f59c42d2     NaN        NaN                NaN
# 39df2d4d-6954-4abf-909f-7ab27d22870f     NaN        NaN                NaN
#
#                                      cam:dataFim cam:dataInicio  \
# slp:resource_uri
# 9589fe93-2270-4940-be3c-706111bf6b69         NaN     2015-02-01
# e896acb8-0da3-4e4a-b235-355c1a01f7cb         NaN     2015-02-01
# 30eb6da8-3308-45a0-bfd8-0f6f9884133c         NaN     2015-02-01
# 76e294dc-7b1a-48d5-8f15-6888f59c42d2  2017-10-30     2015-02-01
# 39df2d4d-6954-4abf-909f-7ab27d22870f         NaN     2015-02-01
#
#                                      cam:siglaUFRepresentacao  \
# slp:resource_uri
# 9589fe93-2270-4940-be3c-706111bf6b69                       AC
# e896acb8-0da3-4e4a-b235-355c1a01f7cb                       PB
# 30eb6da8-3308-45a0-bfd8-0f6f9884133c                       BA
# 76e294dc-7b1a-48d5-8f15-6888f59c42d2                       MT
# 39df2d4d-6954-4abf-909f-7ab27d22870f                       RS
#
#                                                                 org:member  \
# slp:resource_uri
# 9589fe93-2270-4940-be3c-706111bf6b69  64965d06-916a-4ef9-a8c7-886055dc979e
# e896acb8-0da3-4e4a-b235-355c1a01f7cb  908bcac7-6fc7-4957-9ae9-00a46ad10a37
# 30eb6da8-3308-45a0-bfd8-0f6f9884133c  e4e93a22-8177-400a-8231-2e8ae9d06a12
# 76e294dc-7b1a-48d5-8f15-6888f59c42d2  0a39e693-7990-4118-8637-278d778df124
# 39df2d4d-6954-4abf-909f-7ab27d22870f  abf442cf-ef29-40f6-8929-9a4066570ed2
#
#                                                                   org:post  \
# slp:resource_uri
# 9589fe93-2270-4940-be3c-706111bf6b69  66884075-6a00-485e-9dc9-792f9b34e035
# e896acb8-0da3-4e4a-b235-355c1a01f7cb  a8b6f47f-5ff8-489b-8c27-f6880bc0fb54
# 30eb6da8-3308-45a0-bfd8-0f6f9884133c  826e5566-26d8-4dfd-ad92-c81039336f0e
# 76e294dc-7b1a-48d5-8f15-6888f59c42d2  fca05d26-d58d-4289-b0d9-ecffccf678d4
# 39df2d4d-6954-4abf-909f-7ab27d22870f  70fd1e05-d6d4-46ca-98bf-82a207d04d7c
#
#                                                                 org:postIn  \
# slp:resource_uri
# 9589fe93-2270-4940-be3c-706111bf6b69  c8f660fd-7d0b-48e5-8513-2f7f0bb5f91c
# e896acb8-0da3-4e4a-b235-355c1a01f7cb  c8f660fd-7d0b-48e5-8513-2f7f0bb5f91c
# 30eb6da8-3308-45a0-bfd8-0f6f9884133c  c8f660fd-7d0b-48e5-8513-2f7f0bb5f91c
# 76e294dc-7b1a-48d5-8f15-6888f59c42d2  c8f660fd-7d0b-48e5-8513-2f7f0bb5f91c
# 39df2d4d-6954-4abf-909f-7ab27d22870f  c8f660fd-7d0b-48e5-8513-2f7f0bb5f91c
#
#                                                                   org:role  \
# slp:resource_uri
# 9589fe93-2270-4940-be3c-706111bf6b69  b27beba7-ca02-4041-a9e0-1793bcd141fe
# e896acb8-0da3-4e4a-b235-355c1a01f7cb  b27beba7-ca02-4041-a9e0-1793bcd141fe
# 30eb6da8-3308-45a0-bfd8-0f6f9884133c  b27beba7-ca02-4041-a9e0-1793bcd141fe
# 76e294dc-7b1a-48d5-8f15-6888f59c42d2  b27beba7-ca02-4041-a9e0-1793bcd141fe
# 39df2d4d-6954-4abf-909f-7ab27d22870f  b27beba7-ca02-4041-a9e0-1793bcd141fe
#
#                                       sen:CodigoMandato sen:DataDesfiliacao  \
# slp:resource_uri
# 9589fe93-2270-4940-be3c-706111bf6b69                NaN                 NaN
# e896acb8-0da3-4e4a-b235-355c1a01f7cb                NaN                 NaN
# 30eb6da8-3308-45a0-bfd8-0f6f9884133c                NaN                 NaN
# 76e294dc-7b1a-48d5-8f15-6888f59c42d2                NaN                 NaN
# 39df2d4d-6954-4abf-909f-7ab27d22870f                NaN                 NaN
#
#                                      sen:DataFiliacao sen:SiglaPartido  \
# slp:resource_uri
# 9589fe93-2270-4940-be3c-706111bf6b69              NaN              NaN
# e896acb8-0da3-4e4a-b235-355c1a01f7cb              NaN              NaN
# 30eb6da8-3308-45a0-bfd8-0f6f9884133c              NaN              NaN
# 76e294dc-7b1a-48d5-8f15-6888f59c42d2              NaN              NaN
# 39df2d4d-6954-4abf-909f-7ab27d22870f              NaN              NaN
#
#                                      sen:UfParlamentar
# slp:resource_uri
# 9589fe93-2270-4940-be3c-706111bf6b69               NaN
# e896acb8-0da3-4e4a-b235-355c1a01f7cb               NaN
# 30eb6da8-3308-45a0-bfd8-0f6f9884133c               NaN
# 76e294dc-7b1a-48d5-8f15-6888f59c42d2               NaN
# 39df2d4d-6954-4abf-909f-7ab27d22870f               NaN

# %%
filename = '{:}memberships.csv'.format(SLP_PATH)
df.to_csv(filename, sep=';', index=True, encoding='utf-8')
