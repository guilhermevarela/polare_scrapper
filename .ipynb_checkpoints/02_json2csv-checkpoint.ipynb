# %%
import json 
import pandas as pd

# %%
with open('datasets/congressmen-55.json', mode='r') as f:
    congressmen = json.load(f)
f.close()
df_deputados = pd.DataFrame.from_dict(congressmen)
df_deputados.head()
# Out:
#   cam:dataFalecimento cam:dataNascimento                          cam:email  \
# 0                None         1950-01-08      dep.afonsomotta@camara.gov.br
# 1                None         1980-07-21   dep.alexandrebaldy@camara.gov.br
# 2                None         1942-04-26  dep.beneditadasilva@camara.gov.br
# 3                None         1976-10-23         dep.alanrick@camara.gov.br
# 4                None         1979-08-22      dep.alexmanente@camara.gov.br
#
#   cam:ideCadastro                       cam:nomeCivil  \
# 0          178835             AFONSO ANTUNES DA MOTTA
# 1          178875  ALEXANDRE BALDY DE SANT'ANNA BRAGA
# 2           73701     BENEDITA SOUZA DA SILVA SAMPAIO
# 3          178836                   ALAN RICK MIRANDA
# 4          178972               ALEX SPINELLI MANENTE
#
#   cam:nomeParlamentarAtual                                  cam:nomeProfissao  \
# 0             AFONSO MOTTA                                        Advogado(a)
# 1          ALEXANDRE BALDY                                               None
# 2        BENEDITA DA SILVA  Assistente Social, Auxiliar de Enfermagem, Pro...
# 3                ALAN RICK              Administrador de Empresas, Jornalista
# 4             ALEX MANENTE                               Bacharel  em Direito
#
#   cam:sexo              slp:old_resource_uri  \
# 0        M  0eca4711b6022ab099135f54dfe60590
# 1        M  16c1ee98fe15746427b1ae09a3102f15
# 2        F  7640b6ed7ac6123c9016ee426aa357e6
# 3        M  3f8ce45065ead34564ffbb987a294be7
# 4        M  95790d526cceac0ff7d0947aa429a486
#
#                        slp:resource_uri
# 0  58832b7d-e94e-40a8-a840-500cd103ba58
# 1  1281c859-0110-4827-ad8e-e3311a35fb36
# 2  57965c09-e603-4507-9c5a-5628a850ace9
# 3  db882a61-939d-4a79-954e-9752e1eb808a
# 4  b0c1ef2b-7213-4bb0-8fd9-4bfdb40daa60

# %%
df.to_csv('datasets/deputados-55.csv', sep= ';', index_col=None, encoding= 'utf-8')
