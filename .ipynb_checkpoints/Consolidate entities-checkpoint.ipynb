# %% [markdown]
#  # Consolidate Entities
#  All csv files under slp/__entity__/ into one single file representing all terms entities.
#
#  Please run __Senators__ and __Congressmen__ notebooks in order to update the files to the latest state.

# %%
import glob # linux glob wrapper allows us to list directory using regex expressions
import pandas as pd # provides join functionality and named-column manipulation
import os
SLP_PATH = 'datasets/slp/'
AGENTS_PATH = '{:}agents/'.format(SLP_PATH)
ORGANIZATIONS_PATH = '{:}organizations/'.format(SLP_PATH)
MEMBERSHIPS_PATH = '{:}memberships/'.format(SLP_PATH)
ROLES_PATH = '{:}roles/'.format(SLP_PATH)
POSTS_PATH = '{:}posts/'.format(SLP_PATH)

# %%
def upsert_by_prov(entity_path, prov):
    '''
        Performs upsert (Update/Insert) of all files with the same provenance
        
        args:
            entity_path .: string containing the path
            prov        .: string in ('cam', 'sen', 'tse')
        
    '''
    provs = ('cam', 'sen', 'slp', 'tse')
    if prov not in provs:
        raise ValueError('Supported provs are in {:} got {:}'.format(provs,prov))    

    df = None    
    # Gets every directory under entity path - with terms sorted asc    
    entity_terms = sorted( glob.glob('{:}*[0-9]'.format(entity_path)) )
    for et in entity_terms:
        filenames = glob.glob('{:}/*{:}.csv'.format(et, prov))
        df = pd.read_csv(filenames[0], sep= ';', header=0, index_col='slp:resource_uri', encoding='utf-8')
        
        for fn in filenames[1:]:
            _df = pd.read_csv(fn, sep= ';', header=0, index_col='slp:resource_uri', encoding='utf-8')            
            # upsert : concatenate or insert
            df = pd.concat([df[~df.index.isin(_df.index)], _df])

    return df

# %% [markdown]
#  ## 1. Agents
#
#  ### 1.1 Upsert camara

# %%
dataframes = [] 
df = upsert_by_prov(AGENTS_PATH, 'cam')
print('Table camara shape:', df.shape)
columns = df.columns
dataframes.append(df)
df.head()
# Out:
# Table camara shape: (606, 5)
#                                      cam:dataFalecimento cam:dataNascimento  \
# slp:resource_uri
# 64965d06-916a-4ef9-a8c7-886055dc979e                 NaN         1976-10-23
# 908bcac7-6fc7-4957-9ae9-00a46ad10a37                 NaN         1969-02-13
# 5ff9cfe9-2fee-47b6-b7ac-a1cb282236be                 NaN         1987-02-10
# e4e93a22-8177-400a-8231-2e8ae9d06a12                 NaN         1960-10-15
# 0a39e693-7990-4118-8637-278d778df124                 NaN         1956-02-05
#
#                                       cam:ideCadastro  \
# slp:resource_uri
# 64965d06-916a-4ef9-a8c7-886055dc979e           178836
# 908bcac7-6fc7-4957-9ae9-00a46ad10a37           160527
# 5ff9cfe9-2fee-47b6-b7ac-a1cb282236be           160582
# e4e93a22-8177-400a-8231-2e8ae9d06a12           160508
# 0a39e693-7990-4118-8637-278d778df124           178903
#
#                                                            cam:nomeCivil  \
# slp:resource_uri
# 64965d06-916a-4ef9-a8c7-886055dc979e                   ALAN RICK MIRANDA
# 908bcac7-6fc7-4957-9ae9-00a46ad10a37    AGUINALDO VELLOSO BORGES RIBEIRO
# 5ff9cfe9-2fee-47b6-b7ac-a1cb282236be  JOSÉ ALBERTO OLIVEIRA VELOSO FILHO
# e4e93a22-8177-400a-8231-2e8ae9d06a12            AFONSO BANDEIRA FLORENCE
# 0a39e693-7990-4118-8637-278d778df124           ADILTON DOMINGOS SACHETTI
#
#                                      cam:nomeParlamentarAtual
# slp:resource_uri
# 64965d06-916a-4ef9-a8c7-886055dc979e                ALAN RICK
# 908bcac7-6fc7-4957-9ae9-00a46ad10a37        AGUINALDO RIBEIRO
# 5ff9cfe9-2fee-47b6-b7ac-a1cb282236be            ALBERTO FILHO
# e4e93a22-8177-400a-8231-2e8ae9d06a12          AFONSO FLORENCE
# 0a39e693-7990-4118-8637-278d778df124         ADILTON SACHETTI

# %% [markdown]
#  ### 1.2 Upsert senado

# %%
df  = upsert_by_prov(AGENTS_PATH, 'sen')
print('Table senado shape:', df.shape)
columns = df.columns.union(columns)
dataframes.append(df)
df.head()
# Out:
# Table senado shape: (252, 3)
#                                       sen:CodigoParlamentar  \
# slp:resource_uri
# 828a0e78-b457-47de-8112-a7cce8d24563                   5573
# 59888f36-89fc-40e9-adf7-e95bb4906eb2                    739
# 94be5f0e-2cc9-488b-bb32-335a44eb4f1b                   5108
# 40260ab9-9261-46b9-8ab3-3c569dfa8b24                   5136
# ad36f1e7-f24a-4f51-9f44-c45468e0d4a1                   5623
#
#                                        sen:NomeCompletoParlamentar  \
# slp:resource_uri
# 828a0e78-b457-47de-8112-a7cce8d24563        Abel Rebouças São José
# 59888f36-89fc-40e9-adf7-e95bb4906eb2      Ciro Nogueira Lima Filho
# 94be5f0e-2cc9-488b-bb32-335a44eb4f1b     José Aparecido dos Santos
# 40260ab9-9261-46b9-8ab3-3c569dfa8b24        Cesar Antonio de Souza
# ad36f1e7-f24a-4f51-9f44-c45468e0d4a1  Christopher Belchior Goulart
#
#                                          sen:NomeParlamentar
# slp:resource_uri
# 828a0e78-b457-47de-8112-a7cce8d24563           Abel Rebouças
# 59888f36-89fc-40e9-adf7-e95bb4906eb2           Ciro Nogueira
# 94be5f0e-2cc9-488b-bb32-335a44eb4f1b          Cidinho Santos
# 40260ab9-9261-46b9-8ab3-3c569dfa8b24  Cesar Antonio de Souza
# ad36f1e7-f24a-4f51-9f44-c45468e0d4a1     Christopher Goulart

# %% [markdown]
#  ### 1.3 Integrate

# %%
for _df in dataframes:
    _df = _df.reindex(columns=columns, fill_value=None)

df = pd.concat(dataframes, axis=0)    
print('Table agents', _df.shape)
df.head()
# Out:
# Table agents (252, 8)
#                                      cam:dataFalecimento cam:dataNascimento  \
# slp:resource_uri
# 64965d06-916a-4ef9-a8c7-886055dc979e                 NaN         1976-10-23
# 908bcac7-6fc7-4957-9ae9-00a46ad10a37                 NaN         1969-02-13
# 5ff9cfe9-2fee-47b6-b7ac-a1cb282236be                 NaN         1987-02-10
# e4e93a22-8177-400a-8231-2e8ae9d06a12                 NaN         1960-10-15
# 0a39e693-7990-4118-8637-278d778df124                 NaN         1956-02-05
#
#                                       cam:ideCadastro  \
# slp:resource_uri
# 64965d06-916a-4ef9-a8c7-886055dc979e         178836.0
# 908bcac7-6fc7-4957-9ae9-00a46ad10a37         160527.0
# 5ff9cfe9-2fee-47b6-b7ac-a1cb282236be         160582.0
# e4e93a22-8177-400a-8231-2e8ae9d06a12         160508.0
# 0a39e693-7990-4118-8637-278d778df124         178903.0
#
#                                                            cam:nomeCivil  \
# slp:resource_uri
# 64965d06-916a-4ef9-a8c7-886055dc979e                   ALAN RICK MIRANDA
# 908bcac7-6fc7-4957-9ae9-00a46ad10a37    AGUINALDO VELLOSO BORGES RIBEIRO
# 5ff9cfe9-2fee-47b6-b7ac-a1cb282236be  JOSÉ ALBERTO OLIVEIRA VELOSO FILHO
# e4e93a22-8177-400a-8231-2e8ae9d06a12            AFONSO BANDEIRA FLORENCE
# 0a39e693-7990-4118-8637-278d778df124           ADILTON DOMINGOS SACHETTI
#
#                                      cam:nomeParlamentarAtual  \
# slp:resource_uri
# 64965d06-916a-4ef9-a8c7-886055dc979e                ALAN RICK
# 908bcac7-6fc7-4957-9ae9-00a46ad10a37        AGUINALDO RIBEIRO
# 5ff9cfe9-2fee-47b6-b7ac-a1cb282236be            ALBERTO FILHO
# e4e93a22-8177-400a-8231-2e8ae9d06a12          AFONSO FLORENCE
# 0a39e693-7990-4118-8637-278d778df124         ADILTON SACHETTI
#
#                                       sen:CodigoParlamentar  \
# slp:resource_uri
# 64965d06-916a-4ef9-a8c7-886055dc979e                    NaN
# 908bcac7-6fc7-4957-9ae9-00a46ad10a37                    NaN
# 5ff9cfe9-2fee-47b6-b7ac-a1cb282236be                    NaN
# e4e93a22-8177-400a-8231-2e8ae9d06a12                    NaN
# 0a39e693-7990-4118-8637-278d778df124                    NaN
#
#                                      sen:NomeCompletoParlamentar  \
# slp:resource_uri
# 64965d06-916a-4ef9-a8c7-886055dc979e                         NaN
# 908bcac7-6fc7-4957-9ae9-00a46ad10a37                         NaN
# 5ff9cfe9-2fee-47b6-b7ac-a1cb282236be                         NaN
# e4e93a22-8177-400a-8231-2e8ae9d06a12                         NaN
# 0a39e693-7990-4118-8637-278d778df124                         NaN
#
#                                      sen:NomeParlamentar
# slp:resource_uri
# 64965d06-916a-4ef9-a8c7-886055dc979e                 NaN
# 908bcac7-6fc7-4957-9ae9-00a46ad10a37                 NaN
# 5ff9cfe9-2fee-47b6-b7ac-a1cb282236be                 NaN
# e4e93a22-8177-400a-8231-2e8ae9d06a12                 NaN
# 0a39e693-7990-4118-8637-278d778df124                 NaN

# %% [markdown]
#  ### 1.4 Save

# %%
filename = '{:}agents.csv'.format(SLP_PATH)
df.to_csv(filename, sep=';', index=True, encoding='utf-8')

# %% [markdown]
#  ## 2. Memberships
#  ### 2.1 Upsert camara

# %%
dataframes=[]
df = upsert_by_prov(MEMBERSHIPS_PATH, 'cam')
columns = df.columns
dataframes.append(df)
print(df.shape)
df.head()
# Out:
# (1814, 6)
#                                      cam:finishDate cam:sigla  \
# slp:resource_uri
# 9589fe93-2270-4940-be3c-706111bf6b69            NaN       NaN
# e896acb8-0da3-4e4a-b235-355c1a01f7cb            NaN       NaN
# 30eb6da8-3308-45a0-bfd8-0f6f9884133c            NaN       NaN
# 76e294dc-7b1a-48d5-8f15-6888f59c42d2     2017-10-30       NaN
# 39df2d4d-6954-4abf-909f-7ab27d22870f            NaN       NaN
#
#                                      cam:siglaUFRepresentacao cam:startDate  \
# slp:resource_uri
# 9589fe93-2270-4940-be3c-706111bf6b69                       AC    2015-02-01
# e896acb8-0da3-4e4a-b235-355c1a01f7cb                       PB    2015-02-01
# 30eb6da8-3308-45a0-bfd8-0f6f9884133c                       BA    2015-02-01
# 76e294dc-7b1a-48d5-8f15-6888f59c42d2                       MT    2015-02-01
# 39df2d4d-6954-4abf-909f-7ab27d22870f                       RS    2015-02-01
#
#                                                                 org:member  \
# slp:resource_uri
# 9589fe93-2270-4940-be3c-706111bf6b69  64965d06-916a-4ef9-a8c7-886055dc979e
# e896acb8-0da3-4e4a-b235-355c1a01f7cb  908bcac7-6fc7-4957-9ae9-00a46ad10a37
# 30eb6da8-3308-45a0-bfd8-0f6f9884133c  e4e93a22-8177-400a-8231-2e8ae9d06a12
# 76e294dc-7b1a-48d5-8f15-6888f59c42d2  0a39e693-7990-4118-8637-278d778df124
# 39df2d4d-6954-4abf-909f-7ab27d22870f  abf442cf-ef29-40f6-8929-9a4066570ed2
#
#                                                                   org:role
# slp:resource_uri
# 9589fe93-2270-4940-be3c-706111bf6b69  22a2ecf6-5f03-4da9-bc89-48319d152403
# e896acb8-0da3-4e4a-b235-355c1a01f7cb  dc66ab57-90b8-437b-a29c-aae35cbf2ac1
# 30eb6da8-3308-45a0-bfd8-0f6f9884133c  467f2a3e-6c7b-4234-9f62-27cf83588db0
# 76e294dc-7b1a-48d5-8f15-6888f59c42d2  c2d4abc4-a53c-439b-92af-a529c9edd339
# 39df2d4d-6954-4abf-909f-7ab27d22870f  7f059d97-18e2-4053-8116-43636eab4de2

# %% [markdown]
#  ### 2.2 Upsert senado

# %%
df  = upsert_by_prov(MEMBERSHIPS_PATH, 'sen')
print('Table senado shape:', df.shape)
columns = df.columns.union(columns)
dataframes.append(df)
df.head()
# Out:
# Table senado shape: (856, 10)
#                                       NumeroLegislatura  \
# slp:resource_uri
# 0577ae6b-9fa4-4ff0-ac19-9dd5cd3598d1                NaN
# b2ec603a-26b8-4e59-8a59-624d2f0973ac                NaN
# 3cf1400f-9fe7-4552-99ac-d0a4a52a1510                NaN
# da9f5ea7-2636-4240-af94-94e0df597ae9                NaN
# 89a85f62-3dce-499c-a72a-0917f5bf5240                NaN
#
#                                                                 org:member  \
# slp:resource_uri
# 0577ae6b-9fa4-4ff0-ac19-9dd5cd3598d1  85e8b745-786b-4782-a8a1-e3b3164a3f22
# b2ec603a-26b8-4e59-8a59-624d2f0973ac  85e8b745-786b-4782-a8a1-e3b3164a3f22
# 3cf1400f-9fe7-4552-99ac-d0a4a52a1510  85e8b745-786b-4782-a8a1-e3b3164a3f22
# da9f5ea7-2636-4240-af94-94e0df597ae9  85e8b745-786b-4782-a8a1-e3b3164a3f22
# 89a85f62-3dce-499c-a72a-0917f5bf5240  85e8b745-786b-4782-a8a1-e3b3164a3f22
#
#                                                                   org:role  \
# slp:resource_uri
# 0577ae6b-9fa4-4ff0-ac19-9dd5cd3598d1  5fd22d1b-7488-4dd0-b9cd-80504e6fd655
# b2ec603a-26b8-4e59-8a59-624d2f0973ac  164d0752-6038-4c41-b6e2-faed52cb0d7b
# 3cf1400f-9fe7-4552-99ac-d0a4a52a1510  747e074a-1d6e-428d-ac06-7bbd71089874
# da9f5ea7-2636-4240-af94-94e0df597ae9  091020cf-a2a7-4756-8f74-d63299056437
# 89a85f62-3dce-499c-a72a-0917f5bf5240  7954e420-670d-480f-94fc-d7355b046baa
#
#                                       sen:CodigoMandato sen:DataDesfiliacao  \
# slp:resource_uri
# 0577ae6b-9fa4-4ff0-ac19-9dd5cd3598d1                NaN                 NaN
# b2ec603a-26b8-4e59-8a59-624d2f0973ac                NaN                 NaN
# 3cf1400f-9fe7-4552-99ac-d0a4a52a1510                NaN          2004-02-13
# da9f5ea7-2636-4240-af94-94e0df597ae9                NaN                 NaN
# 89a85f62-3dce-499c-a72a-0917f5bf5240                NaN                 NaN
#
#                                      sen:DataFiliacao sen:SiglaPartido  \
# slp:resource_uri
# 0577ae6b-9fa4-4ff0-ac19-9dd5cd3598d1       2015-02-01              PDT
# b2ec603a-26b8-4e59-8a59-624d2f0973ac       2004-02-14               PP
# 3cf1400f-9fe7-4552-99ac-d0a4a52a1510       1999-02-01              PFL
# da9f5ea7-2636-4240-af94-94e0df597ae9       2011-02-03               PR
# 89a85f62-3dce-499c-a72a-0917f5bf5240       2011-02-03              DEM
#
#                                      sen:UfParlamentar sen:finishDate  \
# slp:resource_uri
# 0577ae6b-9fa4-4ff0-ac19-9dd5cd3598d1               NaN            NaN
# b2ec603a-26b8-4e59-8a59-624d2f0973ac               NaN            NaN
# 3cf1400f-9fe7-4552-99ac-d0a4a52a1510               NaN            NaN
# da9f5ea7-2636-4240-af94-94e0df597ae9               NaN            NaN
# 89a85f62-3dce-499c-a72a-0917f5bf5240               NaN            NaN
#
#                                      sen:startDate
# slp:resource_uri
# 0577ae6b-9fa4-4ff0-ac19-9dd5cd3598d1           NaN
# b2ec603a-26b8-4e59-8a59-624d2f0973ac           NaN
# 3cf1400f-9fe7-4552-99ac-d0a4a52a1510           NaN
# da9f5ea7-2636-4240-af94-94e0df597ae9           NaN
# 89a85f62-3dce-499c-a72a-0917f5bf5240           NaN

# %% [markdown]
#  ### 2.3 Integrate

# %%
for _df in dataframes:
    _df = _df.reindex(columns=columns, fill_value=None)

df = pd.concat(dataframes, axis=0)    
print('Table memberships', df.shape)
df.head()
# Out:
# Table memberships (2670, 14)
#                                       NumeroLegislatura cam:finishDate  \
# slp:resource_uri
# 9589fe93-2270-4940-be3c-706111bf6b69                NaN            NaN
# e896acb8-0da3-4e4a-b235-355c1a01f7cb                NaN            NaN
# 30eb6da8-3308-45a0-bfd8-0f6f9884133c                NaN            NaN
# 76e294dc-7b1a-48d5-8f15-6888f59c42d2                NaN     2017-10-30
# 39df2d4d-6954-4abf-909f-7ab27d22870f                NaN            NaN
#
#                                      cam:sigla cam:siglaUFRepresentacao  \
# slp:resource_uri
# 9589fe93-2270-4940-be3c-706111bf6b69       NaN                       AC
# e896acb8-0da3-4e4a-b235-355c1a01f7cb       NaN                       PB
# 30eb6da8-3308-45a0-bfd8-0f6f9884133c       NaN                       BA
# 76e294dc-7b1a-48d5-8f15-6888f59c42d2       NaN                       MT
# 39df2d4d-6954-4abf-909f-7ab27d22870f       NaN                       RS
#
#                                      cam:startDate  \
# slp:resource_uri
# 9589fe93-2270-4940-be3c-706111bf6b69    2015-02-01
# e896acb8-0da3-4e4a-b235-355c1a01f7cb    2015-02-01
# 30eb6da8-3308-45a0-bfd8-0f6f9884133c    2015-02-01
# 76e294dc-7b1a-48d5-8f15-6888f59c42d2    2015-02-01
# 39df2d4d-6954-4abf-909f-7ab27d22870f    2015-02-01
#
#                                                                 org:member  \
# slp:resource_uri
# 9589fe93-2270-4940-be3c-706111bf6b69  64965d06-916a-4ef9-a8c7-886055dc979e
# e896acb8-0da3-4e4a-b235-355c1a01f7cb  908bcac7-6fc7-4957-9ae9-00a46ad10a37
# 30eb6da8-3308-45a0-bfd8-0f6f9884133c  e4e93a22-8177-400a-8231-2e8ae9d06a12
# 76e294dc-7b1a-48d5-8f15-6888f59c42d2  0a39e693-7990-4118-8637-278d778df124
# 39df2d4d-6954-4abf-909f-7ab27d22870f  abf442cf-ef29-40f6-8929-9a4066570ed2
#
#                                                                   org:role  \
# slp:resource_uri
# 9589fe93-2270-4940-be3c-706111bf6b69  22a2ecf6-5f03-4da9-bc89-48319d152403
# e896acb8-0da3-4e4a-b235-355c1a01f7cb  dc66ab57-90b8-437b-a29c-aae35cbf2ac1
# 30eb6da8-3308-45a0-bfd8-0f6f9884133c  467f2a3e-6c7b-4234-9f62-27cf83588db0
# 76e294dc-7b1a-48d5-8f15-6888f59c42d2  c2d4abc4-a53c-439b-92af-a529c9edd339
# 39df2d4d-6954-4abf-909f-7ab27d22870f  7f059d97-18e2-4053-8116-43636eab4de2
#
#                                       sen:CodigoMandato sen:DataDesfiliacao  \
# slp:resource_uri
# 9589fe93-2270-4940-be3c-706111bf6b69                NaN                 NaN
# e896acb8-0da3-4e4a-b235-355c1a01f7cb                NaN                 NaN
# 30eb6da8-3308-45a0-bfd8-0f6f9884133c                NaN                 NaN
# 76e294dc-7b1a-48d5-8f15-6888f59c42d2                NaN                 NaN
# 39df2d4d-6954-4abf-909f-7ab27d22870f                NaN                 NaN
#
#                                      sen:DataFiliacao sen:SiglaPartido  \
# slp:resource_uri
# 9589fe93-2270-4940-be3c-706111bf6b69              NaN              NaN
# e896acb8-0da3-4e4a-b235-355c1a01f7cb              NaN              NaN
# 30eb6da8-3308-45a0-bfd8-0f6f9884133c              NaN              NaN
# 76e294dc-7b1a-48d5-8f15-6888f59c42d2              NaN              NaN
# 39df2d4d-6954-4abf-909f-7ab27d22870f              NaN              NaN
#
#                                      sen:UfParlamentar sen:finishDate  \
# slp:resource_uri
# 9589fe93-2270-4940-be3c-706111bf6b69               NaN            NaN
# e896acb8-0da3-4e4a-b235-355c1a01f7cb               NaN            NaN
# 30eb6da8-3308-45a0-bfd8-0f6f9884133c               NaN            NaN
# 76e294dc-7b1a-48d5-8f15-6888f59c42d2               NaN            NaN
# 39df2d4d-6954-4abf-909f-7ab27d22870f               NaN            NaN
#
#                                      sen:startDate
# slp:resource_uri
# 9589fe93-2270-4940-be3c-706111bf6b69           NaN
# e896acb8-0da3-4e4a-b235-355c1a01f7cb           NaN
# 30eb6da8-3308-45a0-bfd8-0f6f9884133c           NaN
# 76e294dc-7b1a-48d5-8f15-6888f59c42d2           NaN
# 39df2d4d-6954-4abf-909f-7ab27d22870f           NaN

# %%
filename = '{:}memberships.csv'.format(SLP_PATH)
df.to_csv(filename, sep=';', index=True, encoding='utf-8')

# %% [markdown]
#  ## 3. Roles
#  ### 3.1 Upsert camara

# %%
dataframes=[]
df = upsert_by_prov(ROLES_PATH, 'cam')
columns = df.columns
dataframes.append(df)
print(df.shape)
df.head()
# Out:
# (1814, 1)
#                                      rdfs:label
# slp:resource_uri
# 6a688541-b16a-45ca-8aa9-fa700373279f  Affiliate
# 0661f295-d9de-4230-8d2a-d1074e12dd7d  Affiliate
# 780f42ab-09be-4803-859d-cdf0d5c8e079  Affiliate
# 7156ae83-171d-4d8c-877e-c9a1518e5651  Affiliate
# f3d85b78-f9da-46de-bdd3-afa8aecd6619  Affiliate

# %% [markdown]
#  ### 3.2 Upsert senado

# %%
df = upsert_by_prov(ROLES_PATH, 'sen')
columns = df.columns.union(columns)
dataframes.append(df)
print(df.shape)
df.head()
# Out:
# (856, 1)
#                                      rdfs:label
# slp:resource_uri
# 5fd22d1b-7488-4dd0-b9cd-80504e6fd655  Affiliate
# 164d0752-6038-4c41-b6e2-faed52cb0d7b  Affiliate
# 747e074a-1d6e-428d-ac06-7bbd71089874  Affiliate
# 091020cf-a2a7-4756-8f74-d63299056437  Affiliate
# 7954e420-670d-480f-94fc-d7355b046baa  Affiliate

# %% [markdown]
#  ### 3.3 Integrate

# %%
for _df in dataframes:
    _df = _df.reindex(columns=columns, fill_value=None)

df = pd.concat(dataframes, axis=0)    
print('Table roles', df.shape)
df.head()
# Out:
# Table roles (2670, 1)
#                                      rdfs:label
# slp:resource_uri
# 6a688541-b16a-45ca-8aa9-fa700373279f  Affiliate
# 0661f295-d9de-4230-8d2a-d1074e12dd7d  Affiliate
# 780f42ab-09be-4803-859d-cdf0d5c8e079  Affiliate
# 7156ae83-171d-4d8c-877e-c9a1518e5651  Affiliate
# f3d85b78-f9da-46de-bdd3-afa8aecd6619  Affiliate

# %%
filename = '{:}roles.csv'.format(SLP_PATH)
df.to_csv(filename, sep=';', index=True, encoding='utf-8')

# %% [markdown]
#  ## 4. Posts
#  ### 4.1 Upsert camara

# %%
dataframes=[]
df = upsert_by_prov(POSTS_PATH, 'cam')
columns = df.columns
dataframes.append(df)
print(df.shape)
df.head()
# Out:
# (1814, 2)
#                                                                   org:role  \
# slp:resource_uri
# 35c01901-2cca-4d0f-b244-dd7cf2157137  22a2ecf6-5f03-4da9-bc89-48319d152403
# bfd204ea-f6e1-4e95-878f-e446c2a901fc  dc66ab57-90b8-437b-a29c-aae35cbf2ac1
# 4505615a-02e5-4dd1-8ed4-81e79de0ea54  467f2a3e-6c7b-4234-9f62-27cf83588db0
# ad073298-7f8a-4977-a306-54ee3b3cb906  c2d4abc4-a53c-439b-92af-a529c9edd339
# c98664fd-a4f8-46b0-a198-be4deff2f62a  7f059d97-18e2-4053-8116-43636eab4de2
#
#                                                                 org:postIn
# slp:resource_uri
# 35c01901-2cca-4d0f-b244-dd7cf2157137  c8f660fd-7d0b-48e5-8513-2f7f0bb5f91c
# bfd204ea-f6e1-4e95-878f-e446c2a901fc  c8f660fd-7d0b-48e5-8513-2f7f0bb5f91c
# 4505615a-02e5-4dd1-8ed4-81e79de0ea54  c8f660fd-7d0b-48e5-8513-2f7f0bb5f91c
# ad073298-7f8a-4977-a306-54ee3b3cb906  c8f660fd-7d0b-48e5-8513-2f7f0bb5f91c
# c98664fd-a4f8-46b0-a198-be4deff2f62a  c8f660fd-7d0b-48e5-8513-2f7f0bb5f91c

# %% [markdown]
#  ### 4.2 Upsert senado

# %%
df = upsert_by_prov(POSTS_PATH, 'sen')
columns = df.columns.union(columns)
dataframes.append(df)
print(df.shape)
df.head()
# Out:
# (856, 2)
#                                      org:postIn  \
# slp:resource_uri
# 7b210070-df61-11e7-97e9-c82a144c0a85        NaN
# 7b21152e-df61-11e7-bdcf-c82a144c0a85        NaN
# 7b21046c-df61-11e7-8094-c82a144c0a85        NaN
# 7b211a38-df61-11e7-b1b8-c82a144c0a85        NaN
# 7b20ed7e-df61-11e7-bb65-c82a144c0a85        NaN
#
#                                                                   org:role
# slp:resource_uri
# 7b210070-df61-11e7-97e9-c82a144c0a85  5fd22d1b-7488-4dd0-b9cd-80504e6fd655
# 7b21152e-df61-11e7-bdcf-c82a144c0a85  164d0752-6038-4c41-b6e2-faed52cb0d7b
# 7b21046c-df61-11e7-8094-c82a144c0a85  747e074a-1d6e-428d-ac06-7bbd71089874
# 7b211a38-df61-11e7-b1b8-c82a144c0a85  091020cf-a2a7-4756-8f74-d63299056437
# 7b20ed7e-df61-11e7-bb65-c82a144c0a85  7954e420-670d-480f-94fc-d7355b046baa

# %% [markdown]
#  ### 4.3 Integrate

# %%
for _df in dataframes:
    _df = _df.reindex(columns=columns, fill_value=None)

df = pd.concat(dataframes, axis=0)    
print('Table roles', df.shape)
df.head()
# Out:
# Table roles (2670, 2)
#                                                                 org:postIn  \
# slp:resource_uri
# 35c01901-2cca-4d0f-b244-dd7cf2157137  c8f660fd-7d0b-48e5-8513-2f7f0bb5f91c
# bfd204ea-f6e1-4e95-878f-e446c2a901fc  c8f660fd-7d0b-48e5-8513-2f7f0bb5f91c
# 4505615a-02e5-4dd1-8ed4-81e79de0ea54  c8f660fd-7d0b-48e5-8513-2f7f0bb5f91c
# ad073298-7f8a-4977-a306-54ee3b3cb906  c8f660fd-7d0b-48e5-8513-2f7f0bb5f91c
# c98664fd-a4f8-46b0-a198-be4deff2f62a  c8f660fd-7d0b-48e5-8513-2f7f0bb5f91c
#
#                                                                   org:role
# slp:resource_uri
# 35c01901-2cca-4d0f-b244-dd7cf2157137  22a2ecf6-5f03-4da9-bc89-48319d152403
# bfd204ea-f6e1-4e95-878f-e446c2a901fc  dc66ab57-90b8-437b-a29c-aae35cbf2ac1
# 4505615a-02e5-4dd1-8ed4-81e79de0ea54  467f2a3e-6c7b-4234-9f62-27cf83588db0
# ad073298-7f8a-4977-a306-54ee3b3cb906  c2d4abc4-a53c-439b-92af-a529c9edd339
# c98664fd-a4f8-46b0-a198-be4deff2f62a  7f059d97-18e2-4053-8116-43636eab4de2

# %%
filename = '{:}posts.csv'.format(SLP_PATH)
df.to_csv(filename, sep=';', index=True, encoding='utf-8')

# %% [markdown]
# # 5. Organizations
